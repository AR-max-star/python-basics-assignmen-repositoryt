# %% [markdown]
# <a href="https://colab.research.google.com/github/AR-max-star/python-basics-assignmen-repositoryt/blob/main/Python_Basics_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q:Explain the key feqture of python that makes it popular choice for programming?
#
# Ans:Python is popular because it’s easy to learn, has a simple and readable syntax, and is highly versatile. It supports multiple programming paradigms, comes with a rich standard library, and has a vast ecosystem of third-party libraries for tasks like web development, data analysis, AI, and more. Its active community, cross-platform compatibility, and ability to integrate with other languages make it a go-to choice for beginners and professionals alike.

# %% [markdown]
# Q: Define the role of predefined keywords in python and provide example of how they are used in program?
#
# Ans:Predefine keywords in the python are the keywords that have some specific purpose within the language.These keywords are used to define the structure and flow of a program, such as declaring variables, defining functions, or controlling loops and conditions.
#
#  Example:
#
#        def keyword use for defining a function
#         def add(a,b):
#            return a+b
# Keywords:
#
# 1.Program Structure: Keywords like "if", "else", "while" use for define a condition for a block of progrmand and "for" key word use to running a loop for iteration.
#
#   Example:
#
#       x = 15
#
#       if x > 10:
#           print("x is greater than 10")
#       else:
#           print("x is 10 or less")
#
#
#
#
#
# 2.Data Definition: Keywords like "class", "def", and "lambda" define classes and functions.
#
#        Sort by the second element (scores) using a lambda function
#
#        def sort_student_score(students_list):
#
#          sorted_students = sorted(students, key=lambda x: x[1])
#
#          print("Sorted by scores:", sorted_students)
#
#
#         students = [("Alice", 85), ("Bob", 75), ("Charlie", 90), ("Diana", 80)]
#
#          output:
#
#          Sorted by scores: [('Bob', 75), ('Diana', 80), ('Alice', 85), ('Charlie', 90)]
#
#
#
#
#
#
# 3.Boolean Operations: Keywords like True, "False", and, "or", "not" perform logical operations.
# Example:
#
#        age = 20
#        is_adult = age >= 18
#        has_id = True
#
#        if is_adult and has_id:
#            print("Access granted")
#        else:
#            print("Access denied")
#
#        output:
#        Access granted

# %% [markdown]
# Q: Compare and contrast the mutable and immutable objects in python with example?
#
# Ans: Objects whose value can be changed after creation are the mutable Objects
#  and  whose value cannot be changed after creation those are called immutable objects.
#
#
#
#  Mutable objects:
#
#  Example:
#
# List, Dictionary,Sets
#
#           # List is mutable
#            my_list = [1, 2, 3]
#            print("Original List:", my_list)
#
#            # Modifying the list
#            my_list[0] = 100
#            print("Modified List:", my_list)
#
#            output:
#
#            Original List: [1, 2, 3]
#            Modified List: [100, 2, 3]
#
#
#
# Immutable objects:
#
# Example:
#
#   Tuple,String,Integers,Float
#
#            Tuple is immutable
#
#            my_tuple = (1, 2, 3)
#            print("Original Tuple:", my_tuple)
#
#            Attempting to modify a tuple (this will raise an error)
#
#             my_tuple[0] = 100
#
#             print("Error:", e)
#
#             output: it will throw an error
#
#
#
#
#
# Q:Discusss the different types of operators in python and provide examples how they are used?
#
# Ans: Python supports various types of operators and have precedence and associativity rules that determine the order of evaluation in expressions.
#
#    Arithmetic Operators (+, -, *, /)
#
#    Example:
#
#      x = 10
#      y = 3
#      print(x + y)
#      print(x ** y)
#
#      Output: 13
#      Output: 1000
#
#    Comparison Operators (==, !=, <, >)
#
#    Example:
#
#      x = 5
#      y = 10
#      print(x < y)
#
#      Output: True
#
#
#    Logical Operators (and, or, not)
#
#      Example:
#
#       x = 10
#       y = 20
#       print(x > 5 and y < 30)
#
#       Output: True
#
#
#    Assignment Operators (=, +=, -=, *=, /=)
#
#      Example:
#
#       x = 5
#       x += 2
#       print(x)
#
#        Output: 7
#
#
#
#  Q: Explain the concept of type casting in python with example?
#
#
#  Ans: Type casting is the process of changing one data type to another in Python.Python provides built-in functions for type casting, such as int(), float(), str(), list(), tuple(), dict(), etc.
#
#
#   1.Implicit Typecasting
#
#
#    In implicit casting, Python automatically converts a smaller data type into a larger data type to avoid data loss. This typically happens during arithmetic operations or assignments.
#
#      Example:
#
#
#       x = 5       # Integer
#       y = 2.5     # Float
#
#       result = x + y  # Python automatically converts x to a float
#
#        print(result)
#        print(type(result))
#
#        Output: 7.5
#        Output: <class 'float'>
#
#   2.Explicit Typecasting
#
#   Explicit type casting is done manually using built-in functions like "int()", "float()", "str()", "list()", etc. This is useful when you need to forcefully change a data type.
#
#     Example:
#        num = "123"  # String
#        num_int = int(num)  # Convert string to integer
#
#        print(num_int)       # Output: 123
#        print(type(num_int)) # Output: <class 'int'>

# %% [markdown]
# Q: How do conditional statement work in python? Illustrate example.
#
# Ans: Conditional statements in Python allow you to control the flow of a program based on specific conditions. They evaluate expressions and execute code blocks based on whether the condition is True or False.
#
#
# Example:
#
#
#    if-else Statement:
#
#          age = 15
#          if age >= 18:
#             print("You are an adult.")
#         else:
#            print("You are a minor.")
#
#
#        output:   You are a minor.
#   Nested Conditionals
#
#   Sometimes you may need to put one conditional statement inside another
#
# Example:
#
#           num = 15
#
#       if num > 0:
#          if num % 2 == 0:
#             print("Positive even number")
#          else:
#              print("Positive odd number")
#       else:
#           print("Not a positive number")

# %% [markdown]
# Q: Describe the differnt types of loops in python and thier usecases with example?
#
# Ans: Python supports two primary types of loops "for" and "while". loops allow you to repeatedly execute a block of code while a condition is met or for a defined range of values. Each is use for different tasks.
#
# 1. for Loop
#
# The for loop iterates over a sequence (e.g., list, tuple, string, range) or other iterable objects. It is used when you know the number of iterations or when iterating over a collection.
#
#
#  "for" loop Example:
#
#        Iterate over a list using for loop
#
#         fruits = ["apple", "banana", "cherry"]
#          for fruit in fruits:
#            print(fruit)
#
#
#      To generate some random numbers
#
#       for i in range(1,10):
#          print(i)
#      we can also use "break" to stop the code
#
#       for i in range(1,10):
#          if i==5:
#            break
#          print(i)
#
#       continue: Skips the current iteration and moves to the next
#
#          for i in range(1, 6):
#             if i == 3:
#               continue
#             print(i)
#
# 2. while Loop
#
# The while loop executes a block of code as long as a specified condition is True. It is used when the number of iterations is unknown and depends on a condition.
#
#       Example 1: Counting Down
#
#
#        count = 5
#        while count > 0:
#          print(f"Countdown: {count}")
#          count -= 1
#
#          output:
#          Countdown: 5
#          Countdown: 4
#          Countdown: 3
#          Countdown: 2
#          Countdown: 1
#
# 3. Nested Loops
#
#     You can nest one loop inside another. These are useful when working with multi-dimensional data like matrices or tables.
#
# Example:
#
#        for i in range(1, 4):
#           for j in range(1, 4):
#              print(f"{i} x {j} = {i * j}")
#           print()  # Blank line between tables
#
#
#       output:
#
#       1 x 1 = 1
#       1 x 2 = 2
#       1  x 3 = 3
#
#       2 x 1 = 2
#       2 x 2 = 4
#       2 x 3 = 6
#
#        3 x 1 = 3
#        3 x 2 = 6
#        3 x 3 = 9
